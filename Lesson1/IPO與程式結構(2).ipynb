# %% [markdown]
# ## **IPO與程式結構** (90 min)

# %% [markdown]
# ### **APCS 3-1 input()**
# #### **題目說明：**
# #### 輸入一個名字，輸出歡迎的提示語

# %%
#start

# %% [markdown]
# <br>

# %% [markdown]
# ### **APCS 3-2 IPO 練習**
# #### **什麼是IPO ?**
# *   IPO 是 input, process, output 的縮寫組合
# *   設計程式時，IPO 是理想的程式架構
# *   原則上所有的程式都適用這個執行的流程
#
# ![The-Input-Process-Output-IPO-model.png](data:image/png;base64,...)
#
#
#
#
# #### **題目說明：**
# #### 在台灣使用民國年份作為主要日期的表示方法，但除了民國年以外也有通用的西元年份。
# #### 請寫一個程式輸入民國年，輸出對應的西元年份。
# #### 例如：
# *   民國 109 年 = 西元 2020 年
# *   民國 100 年 = 西元 2011 年

# %% [markdown]
# #### **補充說明：**
# #### 在練習程式的時候，input() 還是使用顯性輸入比較容易除錯

# %%
#start

# %% [markdown]
# <br>

# %% [markdown]
# ### **APCS 3-3 價錢和 (自我挑戰)**
# #### **題目說明:**
# #### 輸入 商品A 和 商品B 的價錢，輸出兩個商品價錢的總和

# %% [markdown]
# #### **解題想法:**
# #### 題目需求輸入兩個商品價格，因此需要使用兩次 input()
# #### 兩次 input() 輸入的數值必須使用不同的變數儲存

# %%
#start

# %% [markdown]
# <br>

# %% [markdown]
# ### **APCS 3-4 split()**
# #### **題目說明:**
# #### 時間換算是程式中很常見的功能，請設計一個程式將時間換算成秒數
# #### 輸入的第一項為分鐘，第二項為秒數
# #### 輸出則為總秒數
# #### 例如:「3 50」代表「3分50秒」

# %%
#start

# %% [markdown]
# <br>

# %% [markdown]
# ### **APCS 3-5 解題心法**
# #### **題目說明：**
# #### 高山和平地會有溫度的落差，主要原因為溫度直減率的關係，大氣對流層中，溫度隨著高度增加而降低的現象。
# #### 平均來說，每上升 100 公尺下降 0.6 度，
# #### 請你設計一個程式，輸入平地的溫度，計算以下三個高山山頂的氣溫
#
# *   台灣玉山高度 3952 公尺
# *   日本富士山高度 3776 公尺
# *   瑞士少女峰高度 4158 公尺

# %% [markdown]
# #### **解題想法：**
# *   說: 說出解程式問題的步驟 (找出輸入、輸出和需要程式計算的項目)
# *   翻: 把說的步驟寫成語法
# *   拆: 如果無法轉成語法，代表說的不夠細，要繼續拆解到能夠用語法表達
# *   作: 實作撰寫程式

# %%
#start

# %% [markdown]
# <br>

# %% [markdown]
# ### **APCS 3-6 連續IPO**
#
# #### **使用Jupyter請用下面方式模擬輸入資料**
# ```python
# import sys, io
#
# DATA = """\
# 3 5
# 12 3
# 5 6
# """
# sys.stdin = io.StringIO(DATA)
# ```
#
# #### **題目說明：**
# #### 將生日的月份和日期加總後對10取餘數，該數字就是屬於個人的生日密碼。
# #### 生日密碼 = (月份+日期)%10

# %%
#start

# %% [markdown]
# <br>

# %% [markdown]
# ## **重點複習**
#
# *   程式執行的主要架構是 IPO。
# *   input() 能夠輸入資料到程式中進行運算。
# *   split() 可以在同一行輸入的字串，切割成多個子字串。
# *   資料型態有助於區別變數的類型。
# *   解題心法具有四個步驟，分別是說、翻、拆、作。
# *   使用 for 迴圈搭配 sys.stdin 的特殊功能，可以製作出連續輸入與輸出資料的效果。
